# %% [markdown]
# ##### CSCI 303
# # Introduction to Data Science
# <p/>
#
# ## Neural Networks
#
# ![artificial NN](https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Colored_neural_network.svg/280px-Colored_neural_network.svg.png)

# %% [markdown]
# # This Lecture
# ---
# - ### History
# - ### Applications (what are NNs good for?)
# - ### Network architectures
# - ### Network construction and training with TensorFlow
#
# ### Supplementary material: 3Blue1Brown videos
# These are some very well produced videos that explain some of the key NN concepts. **Highly recommended!**
#
#  - [What is a Neural Network?](https://www.youtube.com/watch?v=aircAruvnKk)
#  - [Gradient descent](https://www.youtube.com/watch?v=IHZwWFHWa-w&list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi&index=3&t=0s)
#  - [Backpropagation](https://www.youtube.com/watch?v=Ilg3gGewQ5U&list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi&index=4&t=0s)
#  - [Backpropagation calculus](https://www.youtube.com/watch?v=tIeHLnjs5U8&list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi&index=5&t=0s)

# %% [markdown]
# # Biological Inspiration
#
# ### The mammalian brain is a powerful learning machine!
#
# ### Can we mimic the components and learning algorithms?
# - **Components**: Somewhat, yes. The **neurons**.
# - **Learning algorithms**: To date, not so much (for **practical** machine learning algorithms).
#
#
# ### The biological neuron:
# A neuron takes input from many neurons (thousands) and sends output to many neurons (thousands) via connections called **synapses**.
# - In biological brains, there are
#  - approximately **86 billion neurons**.
#  - more than **100 trillion synapses**.
#  - many *types* of neurons.
# - Biological **learning**
#  - **New synapses** are created (especially during first few years of life)
#  - **Existing synapses** are "strengthened" or "weakened"
# - Biological **signals**
#  - **Spikes** are bursts of electrical energy that propagate from one neuron to the next.
#  - **Excitatory neurons** increase spiking of neurons to which they send input.
#    - More excitatory input spikes typically leads to more output spikes, but with a **non-linear relationship**.
#      - Neuron won't create any output spikes if there aren't enough input spikes.
#      - Output spike rate can't go above physiological limit.
#  - **Inhibitory neurons** decrease spiking of neurons to which they send input.
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/4/44/Neuron3.png" width="600">

# %% [markdown]
# # The Artifical Neuron
#
# ### An artificial neuron *weights* its inputs, adds a *bias* term, and then applies a non-linearity (*activation* function).
#
# <img src="https://miro.medium.com/max/3000/1*WRG_Re8vGVuHDYigtq2IBA.jpeg" width="700">

# %% [markdown]
# # Classic neural networks (circa 1980s)
#
# ### Composed of input, output, and "hidden" layers
#
# A [universal function approximator](https://en.wikipedia.org/wiki/Universal_approximation_theorem) that can model any continuous-valued function with asymptotic precision, if there are enough neurons.
#
# Almost always trained by gradient descent (supervised learning), using a specialized implementation called **backpropagation**, which allows for efficient training of **layered** networks like the one in this figure.
#
# The "input **layer**" is a poor name. It is not composed of a layer of artificial neurons. It is just the sample input values that are sent to the hidden layer. Hidden and output layers are composed of neurons.
#
# ![artificial NN](https://upload.wikimedia.org/wikipedia/commons/thumb/4/46/Colored_neural_network.svg/280px-Colored_neural_network.svg.png)
#
# Some aspects of these neural networks originated as far back as the 1940s, but it wasn't until the 1980s that all the pieces came to together and the networks were well understood.

# %% [markdown]
# # Deep neural networks (modern era)
#
# - Composed of many **more layers** (100s sometimes!), neurons, and synapses (weights) than classic networks
# - Use **modern activation functions**, especially rectified linear units (ReLU), rather than sigmoidal
# - Training uses "tricks" to **accelerate training speed** (gradient descent convergence)
# - More layers and neurons means many **more parameters** and thus:
#  - Need for much **larger data sets** for training (typically)
#  - Need for lots of **hardware resources** (memory, processing speed, etc.)
# - Variety of network architectures
#  - Layers of **"fully-connected" neurons**, as in figure below
#  - **Spatially or temporally structured** (further ahead in this lecture)
#
#
# ![deep ANN](https://orbograph.com/wp-content/uploads/2019/01/DeepLearn.png)

# %% [markdown]
# # Activation functions
#
#  - **Sigmoidal** is simple model of activation function of biological neurons
#  - **Rectified Linear (ReLU)** is most common activiation function for artificial neurons
#
# <img src="https://miro.medium.com/max/1192/1*4ZEDRpFuCIpUjNgjDdT2Lg.png" width="800">

# %% [markdown]
# # What tasks are deep NNs good for? Tasks that use *unstructured data*!
#
# Models applied to such tasks are often dubbed **Artificial Intelligence (AI)** rather than Machine Learning or Data Science
#
# ## <span style="color: red;">Object (image) recognition, on photographic images</span>
#
# <img src="https://ruder.io/content/images/2018/07/imagenet_challenge.png" width="800">
#
#
# ## <span style="color: red;">Natural Language Processing</span>
#
# ### <span style="color: red;">Speech recognition</span>
#
# ![speech recognition](https://storage.tweakreviews.com/Gadgets/Speech%20Recognition%20in%20Outlook/Tale%20til%20Tekst.png)
#
# ### <span style="color: red;">Text language translation</span>
#
# <img src="https://2.bp.blogspot.com/-2yoN-i1w6M4/WaiBaF3cEOI/AAAAAAAAB_I/okirZsIxxeQe9Rzh7cl3INMpdqgzvSPXQCLcBGAs/s1600/Screen%2BShot%2B2017-08-31%2Bat%2B2.35.34%2BPM.png" width="600">
#
# ### <span style="color: red;">Chatbots</span>
#
# <img src="https://wordstream-files-prod.s3.amazonaws.com/s3fs-public/styles/simple_image/public/images/chatbots-roof-ai-chatbot.png?Alnlcrl3jJ7XnI5KiDTLqOgGe8a36Wpv&itok=a2OEz102" width="500">
#
# ### <span style="color: red;">Competitive AI "Agents"</span>
# Trained with **Reinforcement Learning (RL)** that leaverages Deep NNs.
#
# #### <span style="color: red;">Agent learning via self-play competition</span>
# OpenAI: "... agents build a series of six distinct strategies and counterstrategies, some of which we did not know our environment supported."
#
# <img src="https://i.ytimg.com/vi/kopoLzvh5jY/maxresdefault.jpg" width="700">
# Self-play YouTube video link: https://www.youtube.com/watch?v=kopoLzvh5jY
#
# ## <span style="color: red;">Physical modeling and sensor processing</span>
#
# ### <span style="color: red;">Titles of some papers and press articles</span>
# - Accelerating Physics-Based Simulations Using Neural Network Proxies: An Application in Oil Reservoir Modeling [link](https://arxiv.org/abs/1906.01510)
# - Deep Learning Accelerates Scientific Simulations up to Two Billion Times [link](https://www.infoq.com/news/2020/03/deep-learning-simulation/)
# - Practical Processing of Mobile Sensor Data for Continual Deep Learning Predictions [link](https://arxiv.org/abs/1705.06224)
#
#
#
# ## But what about structured (tabulated) data?
# - **Structured data** is the type of data we've worked with to date. I.e., data that can be represented in a **table or matrix**, with rows of samples and columns of features.
# - Deep NNs can perform well on structured data (despite wide belief in the mid-2010s that they underperformed traditional methods). However, **many traditional methods perform about as well, and often with lower computational costs**.

# %% [markdown]
# # Neural Network Architectures
# ### Automated discovery of good neural architectures is a very active research area
#
# - Network architectures generally relate to the **type of task** they are used for.
#  - **Feed-forward**
#      - Layered (our examples above)
#      - Convolution (models mammalian vision--we'll use one in the next lecture)
#  - **Recurrent**
#    - Dynamic input (e.g., streaming sensor data)
#    - Short-term memory requirements (language translation)
#  - **Feed-back**
#    - Reinforcement learning
#    - Models of biological networks
#    - "Attention" networks
# - Larger networks (more neurons and synapses/connections) are often better, but harder to train
#
#
# ![encoder-decoder](https://3qeqpr26caki16dnhd19sv6by6v-wpengine.netdna-ssl.com/wp-content/uploads/2017/10/Encoder-Decoder-Architecture-for-Neural-Machine-Translation.png)

# %% [markdown]
# # Training: Gradient Descent and Backpropagation
#
# ### Gradient Descent
#
# - Used for **supervised learning**
# - The algorithm takes **iterative steps**, trying to **find the miminum of an error (cost, loss) function**
# - **Steps**:
#  1. For iteration n, compute difference (error) between network outputs and targets
#  2. Compute derivative of error function, with respet to model parameters
#  3. Adjust model parameters (add/subtract) by the derivative (negative of the gradient), scaled by a step size.
#  4. Repeat for iteration n+1
#
# <img src="https://ml-cheatsheet.readthedocs.io/en/latest/_images/gradient_descent.png" width="600">
#
#
# ### Mini-batch Gradient Descent
#
# - Used to help prevent getting stuck in a local minimum
# - For each iteration, we **compute the error (and derivative) only for a subset of the training samples**
# - Thus, **the error surface is slightly different for each iteration**
# - Imagine a rumbling of the surface in the image above. A ball stuck in a local minimum might be "popped" out of that location, and then start rolling toward a lower minimum.
#
# ### Backpropagation
#
# - Backpropagation is an efficient way to compute gradients in layered NNs.
# - It is derived by using the **Chain Rule** from calculus (see the **3Blue1Brown video**).
# - Steps (vaguely):
#  1. Run your training samples through the network (the "forward pass").
#  2. Compute the error from the network output predictions and the targets.
#  3. **Send that error backwards through the network**. The backwards activations of neurons in layer L, and weights between layer L and L+1, can be used to easily compute the gradient for those weights.
#
# ![backprop](https://i.ytimg.com/vi/Ilg3gGewQ5U/maxresdefault.jpg)

# %% [markdown]
# # Let's code!
#
# ### TensorFlow and PyTorch are the two most popular software tools for working with deep neural networks.  We'll use TensorFlow.
#
# ### We'll create layered network with "fully-connected" or "dense" connections between layers, and apply it to the Iris dataset.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import Normalizer
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)
tf.random.set_seed(0)

# %%
# Import the iris data and create train/test sets
iris = datasets.load_iris()
X = iris.data
y = iris.target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# We'll normalize our data, which often results in better models
transformer = Normalizer().fit(X_train)
X_train = transformer.transform(X_train)
X_test = transformer.transform(X_test)

# Get the number of target classes (which will be 3), and samples (150)
num_classes = len(np.unique(y))
num_samples = len(y)

# %% [markdown]
# ### We'll be using the "Keras" API for TensorFlow. Keras has become a de facto API for creating deep neural networks with TensorFlow, PyTorch, and other NN frameworks.
# https://www.tensorflow.org/guide/keras/overview
#
# ### This is a small dataset, with few features (4) and few samples (150) so we'll use a very small NN model.

# %%
## First we construct our network architecture...

num_hidden = 10 # number of hidden neurons we'll use, in each hidden layer

# We specify the use of a sequential model--that is, a layered, feed-forward model.
model = tf.keras.Sequential()

# Start with a layer of num_hidden neurons, that take in the input features
model.add(layers.Dense(num_hidden, activation='relu'))

# Add a second layer of num_hidden neurons, fully connected to the previous layer
model.add(layers.Dense(num_hidden, activation='relu'))

# Add an output layer, with number of output units equal to our number of classes (irises).
# Again, these neurons are fully connected to those of the previous layers
model.add(layers.Dense(num_classes))


## Now we 'compile' the model. This will make it execute more quickly during training and testing.
#
# - The *optimizer* specifies what our step size and "momentum" factors are, for gradient descent
# - The *loss* function is "cross-entropy", rather than RMSE or other losses we've used
#   in the past. It's very effective when training classification models.
# - The *metrics* argument just lets TensorFlow that we want to record/monitor the model's accuracy
#   scores during training (we might have specified something else, like F1-score).
#
model.compile(optimizer=tf.keras.optimizers.Adam(0.01),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])


## Finally, we fit the model to the data. For each gradient descent iteration we'll use
# a (mini-) batch size of 30. Commonly used batch sizes range from 8 to 32.
# An "epoch" is the number of iterations that is needed such that all the training samples will
# have been used one time in training--thus, 150/30==5, in this case. We train for a lot of
# epochs, to see if the model gets to a good fit, and then starts to overfit.
epochs = 300
batch_size = num_samples//5
history = model.fit(X_train, y_train, epochs=epochs,
                    batch_size=batch_size, validation_data=(X_test, y_test))
# Out:
# Epoch 1/300
# 4/4 [==============================] - 1s 85ms/step - loss: 1.1065 - accuracy: 0.3714 - val_loss: 1.1111 - val_accuracy: 0.2444
# Epoch 2/300
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0835 - accuracy: 0.3714 - val_loss: 1.0682 - val_accuracy: 0.2222
# Epoch 3/300
# 4/4 [==============================] - 0s 12ms/step - loss: 1.0567 - accuracy: 0.4476 - val_loss: 1.0477 - val_accuracy: 0.5556
# Epoch 4/300
# 4/4 [==============================] - 0s 17ms/step - loss: 1.0355 - accuracy: 0.6952 - val_loss: 1.0291 - val_accuracy: 0.6000
# Epoch 5/300
# 4/4 [==============================] - 0s 10ms/step - loss: 1.0119 - accuracy: 0.6952 - val_loss: 1.0063 - val_accuracy: 0.6000
# Epoch 6/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9822 - accuracy: 0.6952 - val_loss: 0.9837 - val_accuracy: 0.6000
# Epoch 7/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.9436 - accuracy: 0.6952 - val_loss: 0.9510 - val_accuracy: 0.6000
# Epoch 8/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.9008 - accuracy: 0.6952 - val_loss: 0.9117 - val_accuracy: 0.6000
# Epoch 9/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.8539 - accuracy: 0.6952 - val_loss: 0.8655 - val_accuracy: 0.6000
# Epoch 10/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.8036 - accuracy: 0.6952 - val_loss: 0.8237 - val_accuracy: 0.6000
# Epoch 11/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.7520 - accuracy: 0.6952 - val_loss: 0.7800 - val_accuracy: 0.6000
# Epoch 12/300
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7024 - accuracy: 0.6952 - val_loss: 0.7231 - val_accuracy: 0.6000
# Epoch 13/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.6524 - accuracy: 0.6952 - val_loss: 0.6794 - val_accuracy: 0.6000
# Epoch 14/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.6092 - accuracy: 0.6952 - val_loss: 0.6373 - val_accuracy: 0.6000
# Epoch 15/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5685 - accuracy: 0.6952 - val_loss: 0.5768 - val_accuracy: 0.6000
# Epoch 16/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.5288 - accuracy: 0.6952 - val_loss: 0.5552 - val_accuracy: 0.6000
# Epoch 17/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.4941 - accuracy: 0.6952 - val_loss: 0.5126 - val_accuracy: 0.6000
# Epoch 18/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.4661 - accuracy: 0.6952 - val_loss: 0.4762 - val_accuracy: 0.6667
# Epoch 19/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4443 - accuracy: 0.8762 - val_loss: 0.4388 - val_accuracy: 0.8667
# Epoch 20/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.4181 - accuracy: 0.9238 - val_loss: 0.4532 - val_accuracy: 0.6889
# Epoch 21/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.4004 - accuracy: 0.7905 - val_loss: 0.4327 - val_accuracy: 0.7556
# Epoch 22/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3812 - accuracy: 0.8762 - val_loss: 0.3831 - val_accuracy: 0.9111
# Epoch 23/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.3587 - accuracy: 0.9429 - val_loss: 0.3878 - val_accuracy: 0.8444
# Epoch 24/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3392 - accuracy: 0.9048 - val_loss: 0.3774 - val_accuracy: 0.8444
# Epoch 25/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.3244 - accuracy: 0.9048 - val_loss: 0.3429 - val_accuracy: 0.8667
# Epoch 26/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.3042 - accuracy: 0.9714 - val_loss: 0.3193 - val_accuracy: 0.9333
# Epoch 27/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2901 - accuracy: 0.9524 - val_loss: 0.3377 - val_accuracy: 0.8667
# Epoch 28/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2699 - accuracy: 0.9333 - val_loss: 0.2955 - val_accuracy: 0.9333
# Epoch 29/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.2617 - accuracy: 0.9619 - val_loss: 0.2778 - val_accuracy: 0.9333
# Epoch 30/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2377 - accuracy: 0.9714 - val_loss: 0.3155 - val_accuracy: 0.8667
# Epoch 31/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2324 - accuracy: 0.9333 - val_loss: 0.2710 - val_accuracy: 0.9333
# Epoch 32/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2121 - accuracy: 0.9714 - val_loss: 0.2461 - val_accuracy: 0.9333
# Epoch 33/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2024 - accuracy: 0.9714 - val_loss: 0.2475 - val_accuracy: 0.9333
# Epoch 34/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1887 - accuracy: 0.9714 - val_loss: 0.2483 - val_accuracy: 0.9333
# Epoch 35/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1799 - accuracy: 0.9714 - val_loss: 0.2229 - val_accuracy: 0.9333
# Epoch 36/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1738 - accuracy: 0.9714 - val_loss: 0.2130 - val_accuracy: 0.9556
# Epoch 37/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1692 - accuracy: 0.9714 - val_loss: 0.2036 - val_accuracy: 0.9778
# Epoch 38/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1642 - accuracy: 0.9524 - val_loss: 0.2454 - val_accuracy: 0.9111
# Epoch 39/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1583 - accuracy: 0.9810 - val_loss: 0.1883 - val_accuracy: 0.9778
# Epoch 40/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1380 - accuracy: 0.9714 - val_loss: 0.2350 - val_accuracy: 0.9111
# Epoch 41/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1440 - accuracy: 0.9524 - val_loss: 0.2022 - val_accuracy: 0.9333
# Epoch 42/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1317 - accuracy: 0.9714 - val_loss: 0.1799 - val_accuracy: 0.9778
# Epoch 43/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1262 - accuracy: 0.9714 - val_loss: 0.1869 - val_accuracy: 0.9556
# Epoch 44/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1225 - accuracy: 0.9714 - val_loss: 0.1800 - val_accuracy: 0.9556
# Epoch 45/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1189 - accuracy: 0.9714 - val_loss: 0.1982 - val_accuracy: 0.9333
# Epoch 46/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1227 - accuracy: 0.9714 - val_loss: 0.1853 - val_accuracy: 0.9556
# Epoch 47/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1140 - accuracy: 0.9714 - val_loss: 0.1728 - val_accuracy: 0.9556
# Epoch 48/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1150 - accuracy: 0.9714 - val_loss: 0.1637 - val_accuracy: 0.9778
# Epoch 49/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1106 - accuracy: 0.9714 - val_loss: 0.1842 - val_accuracy: 0.9333
# Epoch 50/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1049 - accuracy: 0.9714 - val_loss: 0.1621 - val_accuracy: 0.9778
# Epoch 51/300
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0987 - accuracy: 0.9714 - val_loss: 0.1634 - val_accuracy: 0.9556
# Epoch 52/300
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0978 - accuracy: 0.9714 - val_loss: 0.1579 - val_accuracy: 0.9778
# Epoch 53/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0968 - accuracy: 0.9714 - val_loss: 0.1599 - val_accuracy: 0.9556
# Epoch 54/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0940 - accuracy: 0.9714 - val_loss: 0.1658 - val_accuracy: 0.9556
# Epoch 55/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0946 - accuracy: 0.9714 - val_loss: 0.1505 - val_accuracy: 0.9778
# Epoch 56/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1010 - accuracy: 0.9524 - val_loss: 0.1494 - val_accuracy: 0.9778
# Epoch 57/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0880 - accuracy: 0.9714 - val_loss: 0.1595 - val_accuracy: 0.9556
# Epoch 58/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0883 - accuracy: 0.9714 - val_loss: 0.1626 - val_accuracy: 0.9556
# Epoch 59/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1002 - accuracy: 0.9714 - val_loss: 0.1604 - val_accuracy: 0.9556
# Epoch 60/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0852 - accuracy: 0.9810 - val_loss: 0.1370 - val_accuracy: 0.9333
# Epoch 61/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0926 - accuracy: 0.9619 - val_loss: 0.1747 - val_accuracy: 0.9556
# Epoch 62/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0828 - accuracy: 0.9714 - val_loss: 0.1422 - val_accuracy: 0.9778
# Epoch 63/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0907 - accuracy: 0.9714 - val_loss: 0.1541 - val_accuracy: 0.9556
# Epoch 64/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0804 - accuracy: 0.9714 - val_loss: 0.1653 - val_accuracy: 0.9556
# Epoch 65/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0832 - accuracy: 0.9714 - val_loss: 0.1480 - val_accuracy: 0.9556
# Epoch 66/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0918 - accuracy: 0.9810 - val_loss: 0.1406 - val_accuracy: 0.9778
# Epoch 67/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0871 - accuracy: 0.9714 - val_loss: 0.1987 - val_accuracy: 0.9111
# Epoch 68/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0843 - accuracy: 0.9810 - val_loss: 0.1334 - val_accuracy: 0.9778
# Epoch 69/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0826 - accuracy: 0.9619 - val_loss: 0.1449 - val_accuracy: 0.9778
# Epoch 70/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0754 - accuracy: 0.9714 - val_loss: 0.1445 - val_accuracy: 0.9778
# Epoch 71/300
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0746 - accuracy: 0.9714 - val_loss: 0.1399 - val_accuracy: 0.9778
# Epoch 72/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 0.9714 - val_loss: 0.1486 - val_accuracy: 0.9556
# Epoch 73/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0746 - accuracy: 0.9714 - val_loss: 0.1440 - val_accuracy: 0.9778
# Epoch 74/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0832 - accuracy: 0.9714 - val_loss: 0.1385 - val_accuracy: 0.9778
# Epoch 75/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0953 - accuracy: 0.9619 - val_loss: 0.2091 - val_accuracy: 0.9111
# Epoch 76/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0656 - accuracy: 0.9810 - val_loss: 0.1308 - val_accuracy: 0.9111
# Epoch 77/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0946 - accuracy: 0.9524 - val_loss: 0.1424 - val_accuracy: 0.9778
# Epoch 78/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0950 - accuracy: 0.9524 - val_loss: 0.2064 - val_accuracy: 0.9111
# Epoch 79/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0617 - accuracy: 0.9810 - val_loss: 0.1309 - val_accuracy: 0.9111
# Epoch 80/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0902 - accuracy: 0.9524 - val_loss: 0.1359 - val_accuracy: 0.9778
# Epoch 81/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0679 - accuracy: 0.9714 - val_loss: 0.1505 - val_accuracy: 0.9556
# Epoch 82/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0652 - accuracy: 0.9810 - val_loss: 0.1352 - val_accuracy: 0.9778
# Epoch 83/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0665 - accuracy: 0.9714 - val_loss: 0.1366 - val_accuracy: 0.9778
# Epoch 84/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0642 - accuracy: 0.9714 - val_loss: 0.1529 - val_accuracy: 0.9556
# Epoch 85/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0647 - accuracy: 0.9714 - val_loss: 0.1368 - val_accuracy: 0.9778
# Epoch 86/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0635 - accuracy: 0.9810 - val_loss: 0.1384 - val_accuracy: 0.9778
# Epoch 87/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0729 - accuracy: 0.9714 - val_loss: 0.1414 - val_accuracy: 0.9556
# Epoch 88/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0678 - accuracy: 0.9714 - val_loss: 0.1283 - val_accuracy: 0.9778
# Epoch 89/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0733 - accuracy: 0.9714 - val_loss: 0.2048 - val_accuracy: 0.9111
# Epoch 90/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0754 - accuracy: 0.9714 - val_loss: 0.1303 - val_accuracy: 0.9778
# Epoch 91/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0806 - accuracy: 0.9524 - val_loss: 0.1293 - val_accuracy: 0.9778
# Epoch 92/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0589 - accuracy: 0.9810 - val_loss: 0.2016 - val_accuracy: 0.9111
# Epoch 93/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0774 - accuracy: 0.9714 - val_loss: 0.1396 - val_accuracy: 0.9556
# Epoch 94/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0601 - accuracy: 0.9810 - val_loss: 0.1279 - val_accuracy: 0.9778
# Epoch 95/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0661 - accuracy: 0.9714 - val_loss: 0.1400 - val_accuracy: 0.9556
# Epoch 96/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0615 - accuracy: 0.9810 - val_loss: 0.1392 - val_accuracy: 0.9556
# Epoch 97/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0589 - accuracy: 0.9810 - val_loss: 0.1470 - val_accuracy: 0.9556
# Epoch 98/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0618 - accuracy: 0.9714 - val_loss: 0.1476 - val_accuracy: 0.9556
# Epoch 99/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0622 - accuracy: 0.9714 - val_loss: 0.1620 - val_accuracy: 0.9556
# Epoch 100/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0640 - accuracy: 0.9714 - val_loss: 0.1306 - val_accuracy: 0.9778
# Epoch 101/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0593 - accuracy: 0.9714 - val_loss: 0.1467 - val_accuracy: 0.9556
# Epoch 102/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0605 - accuracy: 0.9714 - val_loss: 0.1406 - val_accuracy: 0.9556
# Epoch 103/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0572 - accuracy: 0.9810 - val_loss: 0.1436 - val_accuracy: 0.9556
# Epoch 104/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0577 - accuracy: 0.9810 - val_loss: 0.1403 - val_accuracy: 0.9556
# Epoch 105/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0574 - accuracy: 0.9810 - val_loss: 0.1375 - val_accuracy: 0.9778
# Epoch 106/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9810 - val_loss: 0.1431 - val_accuracy: 0.9556
# Epoch 107/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0567 - accuracy: 0.9810 - val_loss: 0.1361 - val_accuracy: 0.9778
# Epoch 108/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0580 - accuracy: 0.9714 - val_loss: 0.1388 - val_accuracy: 0.9778
# Epoch 109/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0572 - accuracy: 0.9810 - val_loss: 0.1466 - val_accuracy: 0.9556
# Epoch 110/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0567 - accuracy: 0.9810 - val_loss: 0.1519 - val_accuracy: 0.9556
# Epoch 111/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0579 - accuracy: 0.9810 - val_loss: 0.1452 - val_accuracy: 0.9556
# Epoch 112/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0574 - accuracy: 0.9810 - val_loss: 0.1521 - val_accuracy: 0.9556
# Epoch 113/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0567 - accuracy: 0.9810 - val_loss: 0.1433 - val_accuracy: 0.9556
# Epoch 114/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0534 - accuracy: 0.9810 - val_loss: 0.1299 - val_accuracy: 0.9778
# Epoch 115/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0614 - accuracy: 0.9714 - val_loss: 0.1379 - val_accuracy: 0.9778
# Epoch 116/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0574 - accuracy: 0.9714 - val_loss: 0.1432 - val_accuracy: 0.9556
# Epoch 117/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0590 - accuracy: 0.9810 - val_loss: 0.1526 - val_accuracy: 0.9556
# Epoch 118/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0678 - accuracy: 0.9714 - val_loss: 0.1510 - val_accuracy: 0.9556
# Epoch 119/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0529 - accuracy: 0.9810 - val_loss: 0.1294 - val_accuracy: 0.9778
# Epoch 120/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0595 - accuracy: 0.9714 - val_loss: 0.1361 - val_accuracy: 0.9778
# Epoch 121/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0544 - accuracy: 0.9810 - val_loss: 0.1452 - val_accuracy: 0.9556
# Epoch 122/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0576 - accuracy: 0.9714 - val_loss: 0.1563 - val_accuracy: 0.9556
# Epoch 123/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0525 - accuracy: 0.9810 - val_loss: 0.1313 - val_accuracy: 0.9778
# Epoch 124/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0647 - accuracy: 0.9619 - val_loss: 0.1429 - val_accuracy: 0.9556
# Epoch 125/300
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0584 - accuracy: 0.9810 - val_loss: 0.2190 - val_accuracy: 0.9111
# Epoch 126/300
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0703 - accuracy: 0.9714 - val_loss: 0.1294 - val_accuracy: 0.9778
# Epoch 127/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0634 - accuracy: 0.9714 - val_loss: 0.1393 - val_accuracy: 0.9778
# Epoch 128/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0535 - accuracy: 0.9810 - val_loss: 0.1925 - val_accuracy: 0.9556
# Epoch 129/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0594 - accuracy: 0.9714 - val_loss: 0.1331 - val_accuracy: 0.9778
# Epoch 130/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0637 - accuracy: 0.9619 - val_loss: 0.1350 - val_accuracy: 0.9778
# Epoch 131/300
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0572 - accuracy: 0.9714 - val_loss: 0.1812 - val_accuracy: 0.9556
# Epoch 132/300
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0598 - accuracy: 0.9714 - val_loss: 0.1402 - val_accuracy: 0.9556
# Epoch 133/300
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0600 - accuracy: 0.9714 - val_loss: 0.1501 - val_accuracy: 0.9556
# Epoch 134/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0597 - accuracy: 0.9714 - val_loss: 0.1843 - val_accuracy: 0.9556
# Epoch 135/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0569 - accuracy: 0.9810 - val_loss: 0.1311 - val_accuracy: 0.9778
# Epoch 136/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0571 - accuracy: 0.9714 - val_loss: 0.1434 - val_accuracy: 0.9556
# Epoch 137/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0541 - accuracy: 0.9714 - val_loss: 0.1428 - val_accuracy: 0.9556
# Epoch 138/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0516 - accuracy: 0.9810 - val_loss: 0.1614 - val_accuracy: 0.9556
# Epoch 139/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0607 - accuracy: 0.9714 - val_loss: 0.1396 - val_accuracy: 0.9778
# Epoch 140/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0540 - accuracy: 0.9714 - val_loss: 0.1346 - val_accuracy: 0.9778
# Epoch 141/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0577 - accuracy: 0.9714 - val_loss: 0.1525 - val_accuracy: 0.9556
# Epoch 142/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0520 - accuracy: 0.9810 - val_loss: 0.1394 - val_accuracy: 0.9778
# Epoch 143/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0528 - accuracy: 0.9810 - val_loss: 0.1454 - val_accuracy: 0.9556
# Epoch 144/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0640 - accuracy: 0.9714 - val_loss: 0.1380 - val_accuracy: 0.9778
# Epoch 145/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0539 - accuracy: 0.9810 - val_loss: 0.1916 - val_accuracy: 0.9556
# Epoch 146/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0637 - accuracy: 0.9714 - val_loss: 0.1358 - val_accuracy: 0.9778
# Epoch 147/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0713 - accuracy: 0.9619 - val_loss: 0.1370 - val_accuracy: 0.9111
# Epoch 148/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0508 - accuracy: 0.9810 - val_loss: 0.2435 - val_accuracy: 0.9111
# Epoch 149/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0935 - accuracy: 0.9714 - val_loss: 0.1774 - val_accuracy: 0.9556
# Epoch 150/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0539 - accuracy: 0.9714 - val_loss: 0.1312 - val_accuracy: 0.9333
# Epoch 151/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0586 - accuracy: 0.9619 - val_loss: 0.1556 - val_accuracy: 0.9556
# Epoch 152/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0577 - accuracy: 0.9714 - val_loss: 0.1613 - val_accuracy: 0.9556
# Epoch 153/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0521 - accuracy: 0.9810 - val_loss: 0.1346 - val_accuracy: 0.9778
# Epoch 154/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0568 - accuracy: 0.9714 - val_loss: 0.1725 - val_accuracy: 0.9556
# Epoch 155/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0564 - accuracy: 0.9714 - val_loss: 0.1619 - val_accuracy: 0.9556
# Epoch 156/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0519 - accuracy: 0.9810 - val_loss: 0.1405 - val_accuracy: 0.9778
# Epoch 157/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0517 - accuracy: 0.9810 - val_loss: 0.1513 - val_accuracy: 0.9556
# Epoch 158/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0510 - accuracy: 0.9810 - val_loss: 0.1343 - val_accuracy: 0.9778
# Epoch 159/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0527 - accuracy: 0.9810 - val_loss: 0.1532 - val_accuracy: 0.9556
# Epoch 160/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0494 - accuracy: 0.9810 - val_loss: 0.1564 - val_accuracy: 0.9556
# Epoch 161/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0507 - accuracy: 0.9810 - val_loss: 0.1468 - val_accuracy: 0.9556
# Epoch 162/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0500 - accuracy: 0.9810 - val_loss: 0.1502 - val_accuracy: 0.9556
# Epoch 163/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0594 - accuracy: 0.9714 - val_loss: 0.1486 - val_accuracy: 0.9556
# Epoch 164/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0555 - accuracy: 0.9810 - val_loss: 0.1687 - val_accuracy: 0.9556
# Epoch 165/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0546 - accuracy: 0.9810 - val_loss: 0.1455 - val_accuracy: 0.9556
# Epoch 166/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0542 - accuracy: 0.9810 - val_loss: 0.1559 - val_accuracy: 0.9556
# Epoch 167/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0523 - accuracy: 0.9810 - val_loss: 0.1375 - val_accuracy: 0.9778
# Epoch 168/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0543 - accuracy: 0.9714 - val_loss: 0.1584 - val_accuracy: 0.9556
# Epoch 169/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0728 - accuracy: 0.9524 - val_loss: 0.1432 - val_accuracy: 0.9778
# Epoch 170/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0456 - accuracy: 0.9714 - val_loss: 0.2296 - val_accuracy: 0.9333
# Epoch 171/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0717 - accuracy: 0.9714 - val_loss: 0.1360 - val_accuracy: 0.9778
# Epoch 172/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0548 - accuracy: 0.9714 - val_loss: 0.1510 - val_accuracy: 0.9556
# Epoch 173/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0561 - accuracy: 0.9810 - val_loss: 0.1488 - val_accuracy: 0.9556
# Epoch 174/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0507 - accuracy: 0.9810 - val_loss: 0.1402 - val_accuracy: 0.9778
# Epoch 175/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0528 - accuracy: 0.9714 - val_loss: 0.1473 - val_accuracy: 0.9556
# Epoch 176/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0516 - accuracy: 0.9714 - val_loss: 0.1466 - val_accuracy: 0.9556
# Epoch 177/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0532 - accuracy: 0.9810 - val_loss: 0.1550 - val_accuracy: 0.9556
# Epoch 178/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0489 - accuracy: 0.9810 - val_loss: 0.1584 - val_accuracy: 0.9556
# Epoch 179/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0514 - accuracy: 0.9810 - val_loss: 0.1667 - val_accuracy: 0.9556
# Epoch 180/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0625 - accuracy: 0.9810 - val_loss: 0.1448 - val_accuracy: 0.9778
# Epoch 181/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0580 - accuracy: 0.9810 - val_loss: 0.1607 - val_accuracy: 0.9556
# Epoch 182/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0670 - accuracy: 0.9524 - val_loss: 0.1460 - val_accuracy: 0.9556
# Epoch 183/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0398 - accuracy: 0.9810 - val_loss: 0.2574 - val_accuracy: 0.9111
# Epoch 184/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0753 - accuracy: 0.9714 - val_loss: 0.1564 - val_accuracy: 0.9556
# Epoch 185/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0470 - accuracy: 0.9810 - val_loss: 0.1377 - val_accuracy: 0.9778
# Epoch 186/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0567 - accuracy: 0.9619 - val_loss: 0.1734 - val_accuracy: 0.9556
# Epoch 187/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0545 - accuracy: 0.9810 - val_loss: 0.2156 - val_accuracy: 0.9556
# Epoch 188/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0592 - accuracy: 0.9810 - val_loss: 0.1398 - val_accuracy: 0.9778
# Epoch 189/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0511 - accuracy: 0.9714 - val_loss: 0.1433 - val_accuracy: 0.9778
# Epoch 190/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0479 - accuracy: 0.9810 - val_loss: 0.1587 - val_accuracy: 0.9556
# Epoch 191/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0478 - accuracy: 0.9810 - val_loss: 0.1533 - val_accuracy: 0.9556
# Epoch 192/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0471 - accuracy: 0.9810 - val_loss: 0.1474 - val_accuracy: 0.9556
# Epoch 193/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0486 - accuracy: 0.9810 - val_loss: 0.1551 - val_accuracy: 0.9556
# Epoch 194/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0558 - accuracy: 0.9810 - val_loss: 0.1611 - val_accuracy: 0.9556
# Epoch 195/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0522 - accuracy: 0.9714 - val_loss: 0.1447 - val_accuracy: 0.9778
# Epoch 196/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0482 - accuracy: 0.9810 - val_loss: 0.1661 - val_accuracy: 0.9556
# Epoch 197/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0581 - accuracy: 0.9810 - val_loss: 0.1513 - val_accuracy: 0.9556
# Epoch 198/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0676 - accuracy: 0.9619 - val_loss: 0.1382 - val_accuracy: 0.9333
# Epoch 199/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0526 - accuracy: 0.9714 - val_loss: 0.2163 - val_accuracy: 0.9556
# Epoch 200/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0659 - accuracy: 0.9714 - val_loss: 0.1624 - val_accuracy: 0.9556
# Epoch 201/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0873 - accuracy: 0.9429 - val_loss: 0.1427 - val_accuracy: 0.9333
# Epoch 202/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0782 - accuracy: 0.9524 - val_loss: 0.2652 - val_accuracy: 0.9111
# Epoch 203/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0749 - accuracy: 0.9714 - val_loss: 0.1554 - val_accuracy: 0.9556
# Epoch 204/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0663 - accuracy: 0.9524 - val_loss: 0.1461 - val_accuracy: 0.9778
# Epoch 205/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0542 - accuracy: 0.9810 - val_loss: 0.2126 - val_accuracy: 0.9556
# Epoch 206/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0572 - accuracy: 0.9810 - val_loss: 0.1486 - val_accuracy: 0.9556
# Epoch 207/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0492 - accuracy: 0.9714 - val_loss: 0.1435 - val_accuracy: 0.9778
# Epoch 208/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0496 - accuracy: 0.9810 - val_loss: 0.1601 - val_accuracy: 0.9556
# Epoch 209/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0489 - accuracy: 0.9810 - val_loss: 0.1797 - val_accuracy: 0.9556
# Epoch 210/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0473 - accuracy: 0.9810 - val_loss: 0.1454 - val_accuracy: 0.9778
# Epoch 211/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0516 - accuracy: 0.9714 - val_loss: 0.1431 - val_accuracy: 0.9778
# Epoch 212/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0651 - accuracy: 0.9619 - val_loss: 0.1961 - val_accuracy: 0.9556
# Epoch 213/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0567 - accuracy: 0.9714 - val_loss: 0.1409 - val_accuracy: 0.9778
# Epoch 214/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0526 - accuracy: 0.9714 - val_loss: 0.1804 - val_accuracy: 0.9556
# Epoch 215/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0573 - accuracy: 0.9714 - val_loss: 0.1577 - val_accuracy: 0.9556
# Epoch 216/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0547 - accuracy: 0.9714 - val_loss: 0.1422 - val_accuracy: 0.9778
# Epoch 217/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0757 - accuracy: 0.9714 - val_loss: 0.1897 - val_accuracy: 0.9556
# Epoch 218/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0503 - accuracy: 0.9810 - val_loss: 0.1476 - val_accuracy: 0.9111
# Epoch 219/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0822 - accuracy: 0.9524 - val_loss: 0.1708 - val_accuracy: 0.9556
# Epoch 220/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0685 - accuracy: 0.9810 - val_loss: 0.2680 - val_accuracy: 0.9111
# Epoch 221/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0706 - accuracy: 0.9714 - val_loss: 0.1476 - val_accuracy: 0.9778
# Epoch 222/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0485 - accuracy: 0.9714 - val_loss: 0.1428 - val_accuracy: 0.9778
# Epoch 223/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0492 - accuracy: 0.9714 - val_loss: 0.1727 - val_accuracy: 0.9556
# Epoch 224/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0678 - accuracy: 0.9714 - val_loss: 0.2081 - val_accuracy: 0.9556
# Epoch 225/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0530 - accuracy: 0.9810 - val_loss: 0.1416 - val_accuracy: 0.9778
# Epoch 226/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0781 - accuracy: 0.9429 - val_loss: 0.1482 - val_accuracy: 0.9778
# Epoch 227/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0536 - accuracy: 0.9810 - val_loss: 0.1993 - val_accuracy: 0.9556
# Epoch 228/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0634 - accuracy: 0.9810 - val_loss: 0.1536 - val_accuracy: 0.9556
# Epoch 229/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0567 - accuracy: 0.9810 - val_loss: 0.1897 - val_accuracy: 0.9556
# Epoch 230/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0451 - accuracy: 0.9810 - val_loss: 0.1415 - val_accuracy: 0.9778
# Epoch 231/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0560 - accuracy: 0.9619 - val_loss: 0.1512 - val_accuracy: 0.9556
# Epoch 232/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0509 - accuracy: 0.9810 - val_loss: 0.1812 - val_accuracy: 0.9556
# Epoch 233/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0495 - accuracy: 0.9810 - val_loss: 0.1548 - val_accuracy: 0.9556
# Epoch 234/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0487 - accuracy: 0.9810 - val_loss: 0.1528 - val_accuracy: 0.9556
# Epoch 235/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0574 - accuracy: 0.9524 - val_loss: 0.1468 - val_accuracy: 0.9778
# Epoch 236/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0551 - accuracy: 0.9714 - val_loss: 0.1818 - val_accuracy: 0.9556
# Epoch 237/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0474 - accuracy: 0.9810 - val_loss: 0.1477 - val_accuracy: 0.9778
# Epoch 238/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0594 - accuracy: 0.9619 - val_loss: 0.1609 - val_accuracy: 0.9556
# Epoch 239/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0948 - accuracy: 0.9714 - val_loss: 0.2450 - val_accuracy: 0.9333
# Epoch 240/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0515 - accuracy: 0.9619 - val_loss: 0.1597 - val_accuracy: 0.9111
# Epoch 241/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1058 - accuracy: 0.9429 - val_loss: 0.1768 - val_accuracy: 0.9556
# Epoch 242/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1268 - accuracy: 0.9619 - val_loss: 0.3225 - val_accuracy: 0.9111
# Epoch 243/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1198 - accuracy: 0.9429 - val_loss: 0.1612 - val_accuracy: 0.9111
# Epoch 244/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0641 - accuracy: 0.9714 - val_loss: 0.2061 - val_accuracy: 0.9556
# Epoch 245/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0939 - accuracy: 0.9714 - val_loss: 0.3061 - val_accuracy: 0.9111
# Epoch 246/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0713 - accuracy: 0.9714 - val_loss: 0.1442 - val_accuracy: 0.9778
# Epoch 247/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0741 - accuracy: 0.9619 - val_loss: 0.1417 - val_accuracy: 0.9333
# Epoch 248/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0463 - accuracy: 0.9714 - val_loss: 0.2122 - val_accuracy: 0.9556
# Epoch 249/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0646 - accuracy: 0.9810 - val_loss: 0.1856 - val_accuracy: 0.9556
# Epoch 250/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0557 - accuracy: 0.9714 - val_loss: 0.1439 - val_accuracy: 0.9333
# Epoch 251/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0554 - accuracy: 0.9619 - val_loss: 0.2283 - val_accuracy: 0.9333
# Epoch 252/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0701 - accuracy: 0.9714 - val_loss: 0.2234 - val_accuracy: 0.9333
# Epoch 253/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0439 - accuracy: 0.9810 - val_loss: 0.1423 - val_accuracy: 0.9333
# Epoch 254/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0621 - accuracy: 0.9619 - val_loss: 0.1497 - val_accuracy: 0.9556
# Epoch 255/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0723 - accuracy: 0.9714 - val_loss: 0.2342 - val_accuracy: 0.9333
# Epoch 256/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0676 - accuracy: 0.9810 - val_loss: 0.1455 - val_accuracy: 0.9778
# Epoch 257/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0550 - accuracy: 0.9810 - val_loss: 0.1584 - val_accuracy: 0.9556
# Epoch 258/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0480 - accuracy: 0.9810 - val_loss: 0.1929 - val_accuracy: 0.9556
# Epoch 259/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0558 - accuracy: 0.9810 - val_loss: 0.1662 - val_accuracy: 0.9556
# Epoch 260/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0498 - accuracy: 0.9714 - val_loss: 0.1431 - val_accuracy: 0.9778
# Epoch 261/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0527 - accuracy: 0.9714 - val_loss: 0.1674 - val_accuracy: 0.9556
# Epoch 262/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0468 - accuracy: 0.9810 - val_loss: 0.1771 - val_accuracy: 0.9556
# Epoch 263/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0476 - accuracy: 0.9810 - val_loss: 0.1575 - val_accuracy: 0.9556
# Epoch 264/300
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0464 - accuracy: 0.9810 - val_loss: 0.1558 - val_accuracy: 0.9556
# Epoch 265/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0511 - accuracy: 0.9714 - val_loss: 0.1555 - val_accuracy: 0.9556
# Epoch 266/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0471 - accuracy: 0.9810 - val_loss: 0.1945 - val_accuracy: 0.9556
# Epoch 267/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0510 - accuracy: 0.9810 - val_loss: 0.1686 - val_accuracy: 0.9556
# Epoch 268/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0461 - accuracy: 0.9810 - val_loss: 0.1501 - val_accuracy: 0.9778
# Epoch 269/300
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0521 - accuracy: 0.9714 - val_loss: 0.1596 - val_accuracy: 0.9556
# Epoch 270/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0483 - accuracy: 0.9810 - val_loss: 0.1799 - val_accuracy: 0.9556
# Epoch 271/300
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0499 - accuracy: 0.9810 - val_loss: 0.1464 - val_accuracy: 0.9778
# Epoch 272/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0523 - accuracy: 0.9810 - val_loss: 0.1661 - val_accuracy: 0.9556
# Epoch 273/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0502 - accuracy: 0.9810 - val_loss: 0.1720 - val_accuracy: 0.9556
# Epoch 274/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0483 - accuracy: 0.9810 - val_loss: 0.1560 - val_accuracy: 0.9556
# Epoch 275/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0517 - accuracy: 0.9810 - val_loss: 0.1733 - val_accuracy: 0.9556
# Epoch 276/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0483 - accuracy: 0.9810 - val_loss: 0.1590 - val_accuracy: 0.9556
# Epoch 277/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0502 - accuracy: 0.9810 - val_loss: 0.1674 - val_accuracy: 0.9556
# Epoch 278/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0452 - accuracy: 0.9810 - val_loss: 0.1489 - val_accuracy: 0.9778
# Epoch 279/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0504 - accuracy: 0.9714 - val_loss: 0.1558 - val_accuracy: 0.9556
# Epoch 280/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0481 - accuracy: 0.9714 - val_loss: 0.1683 - val_accuracy: 0.9556
# Epoch 281/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0446 - accuracy: 0.9810 - val_loss: 0.2067 - val_accuracy: 0.9556
# Epoch 282/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0530 - accuracy: 0.9810 - val_loss: 0.1646 - val_accuracy: 0.9556
# Epoch 283/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0451 - accuracy: 0.9810 - val_loss: 0.1517 - val_accuracy: 0.9778
# Epoch 284/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0515 - accuracy: 0.9714 - val_loss: 0.1589 - val_accuracy: 0.9556
# Epoch 285/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0613 - accuracy: 0.9810 - val_loss: 0.2089 - val_accuracy: 0.9556
# Epoch 286/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0454 - accuracy: 0.9810 - val_loss: 0.1483 - val_accuracy: 0.9778
# Epoch 287/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1094 - accuracy: 0.9429 - val_loss: 0.1471 - val_accuracy: 0.9333
# Epoch 288/300
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0366 - accuracy: 0.9810 - val_loss: 0.2791 - val_accuracy: 0.9111
# Epoch 289/300
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0972 - accuracy: 0.9714 - val_loss: 0.2289 - val_accuracy: 0.9333
# Epoch 290/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0410 - accuracy: 0.9905 - val_loss: 0.1481 - val_accuracy: 0.9333
# Epoch 291/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0656 - accuracy: 0.9619 - val_loss: 0.1542 - val_accuracy: 0.9556
# Epoch 292/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0420 - accuracy: 0.9810 - val_loss: 0.2026 - val_accuracy: 0.9556
# Epoch 293/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0749 - accuracy: 0.9714 - val_loss: 0.2004 - val_accuracy: 0.9556
# Epoch 294/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0850 - accuracy: 0.9524 - val_loss: 0.1536 - val_accuracy: 0.9111
# Epoch 295/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.0553 - accuracy: 0.9714 - val_loss: 0.2069 - val_accuracy: 0.9556
# Epoch 296/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1132 - accuracy: 0.9619 - val_loss: 0.2840 - val_accuracy: 0.9111
# Epoch 297/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0611 - accuracy: 0.9714 - val_loss: 0.1553 - val_accuracy: 0.9111
# Epoch 298/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0755 - accuracy: 0.9619 - val_loss: 0.1683 - val_accuracy: 0.9556
# Epoch 299/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0467 - accuracy: 0.9810 - val_loss: 0.2291 - val_accuracy: 0.9333
# Epoch 300/300
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0669 - accuracy: 0.9810 - val_loss: 0.1690 - val_accuracy: 0.9556

# %%
## We can plot the accuracy scores (for both training and test sets) that were recorded during training, 
#  as well as the cross-entropy losses...

plt.figure(figsize=(15, 5))
fs = 16 # fontsize

# plot loss information for training and testing
plt.subplot(1,2,1)
plt.plot(np.arange(1,epochs+1), history.history['loss'], label='training set loss')
plt.plot(np.arange(1,epochs+1), history.history['val_loss'], label='test set loss')
plt.legend(fontsize=fs)
plt.xlabel('Epoch', fontsize=fs)
plt.ylabel('Losses', fontsize=fs)
plt.grid(True)

# plot accuracy information for training and testing
plt.subplot(1,2,2)
plt.plot(np.arange(1,epochs+1), history.history['accuracy'], label='training set acc')
plt.plot(np.arange(1,epochs+1), history.history['val_accuracy'], label='test set acc')
plt.legend(fontsize=fs)
plt.xlabel('Epoch', fontsize=fs)
plt.ylabel('Accuracies', fontsize=fs)
plt.grid(True)

# %% [markdown]
# # Results
#
# - The training and test set **accuracies** did not diverge, even after many epochs of training.
# - Thus, our model does not suffer from (much) over-fitting.
# - This is likely due to the low number of features, and the compactness of the target clusters in the feature space.
# - The test set **loss** does diverge slightly, however. Suggesting there is some overfitting, but not enough to notably impact the model's classification predictions.

# %% [markdown]
# # Instructor self-promotion!
#
# If you have further interest in the similarities between biological neurons and artificial neurons, you might enjoy this 2019 blog post from Matt Roos.
#
# ### [Deep Learning Neurons versus Biological Neurons](https://towardsdatascience.com/deep-learning-versus-biological-neurons-floating-point-numbers-spikes-and-neurotransmitters-6eebfa3390e9)
#
# <img src="https://miro.medium.com/max/1280/1*2f1GySbEhznZ62KluBRSiA.png" width="400">

# %% [markdown]
# # Next time
#
# - Convolutional neural networks (CNNs): NNs that model the visual system, and perform well on images tasks.
